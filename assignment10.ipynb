# %% [markdown]
# GRAPH
# 5)  인접 행렬을 사용한다. 간선 수가 최대(O(V^2))일 때는 인접 리스트의 공간 이점이 없으나, 인접 행렬을 사용하면 원소를  O(1)에 접근할 수 있으므로 더 효율적이다.
#
# 6) 인접 리스트를 사용한다. 정점 사이에 간선이 드물게 있을 경우, 인접 행렬을 사용한다면 메모리는 반드시 O(V^2)를 사용하는데, 데이터가 없는 자리가 생기므로 메모리를 비효율적으로 사용하게 된다. 반면 인접 리스트는 사용할 데이터만 노드를 추가하면 되므로(O(V+E)) 효율적이다.
#
# 8) 1번이다. 간선 제시 순서대로 DFS 순서를 나열하면, 1,2,3,5,4,6 이다. 이때 DFS(1)에서 직접 호출되는 것은 DFS(2) 뿐이다.
#
# 12)
# (1) 프림
# ![primAIgorithm](prim.jpg)
#
# (2) 크루스칼
# ![kruskalAlgorithm](kruskal.jpg)
#
#
# 16)
# (1) 위상정렬 수도코드
# topologicalSort with STACK:
#     Create STACK
#     Create visited <- false
#     for each vertex v
#         if (!visited[v])
#             DFS(v, visited, STACK)
#     while(!STACK.empty)
#         STACK.pop
#
# DFS(v, visited, STACK)
#     visited <-false
#     for i in Adj[v]
#         if(!visited[i])
#             DFS
#     STACK.push(v)
#
# (2) 스택을 사용한 위상정렬의 가능한 순서는 4가지이다.
#
#
# 17) ![dijkstra](problem17.jpg)
#
# 18) 가중치에 음수가 있는 경우, 잘못 판단하여 확정시켜버린다.
# ![dijkstra2](dijkstra2.jpg)
#
# 22) 음의 사이클이 있는 경우
#
#
# SORTING
#
# 5)
# (1) 선택 정렬
# ![selectionSort](selectionSort.jpg)
#
#
# (2) 버블 정렬
# ![bubble](bubbleSort.jpg)
#
#
# (3) 삽입 정렬
# ![insertion](insertionSort.jpg)
#
#
# 6)
#
# (1) 병합 정렬
# ![merge](mergeSort.jpg)
#
# (2) 힙 정렬
# ![heapSort](heapSort.jpg)
#
# (3) 퀵 정렬
# ![quickSort](quickSort.jpg)
